# %%
import time

start = time.time()

# Example heavy pipeline section
df = spark.sql("""
SELECT *
FROM events_delta
WHERE event_type = 'purchase'
""")

df.count()

end = time.time()

print("Total Runtime:", round(end - start, 2), "seconds")

# %%
df = spark.table("events_delta")

df.count()
df.count()

# %%
df = spark.table("events_delta")

total = df.count()

print(total)

# %%
start = time.time()

spark.table("events_delta").count()
spark.table("events_delta").count()

end = time.time()

print("Inefficient Runtime:", round(end - start, 2))

# %%
start = time.time()

df = spark.table("events_delta")
total = df.count()

end = time.time()

print("Optimized Runtime:", round(end - start, 2))

# %% [markdown]
# # **Day 14**
