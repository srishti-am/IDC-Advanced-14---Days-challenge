# %% [markdown]
# **STEP 0 — Load Full Feature Dataset**
# **We want to score ALL users (not just test set).**

# %%
full_features = spark.table("silver_user_features")

# %% [markdown]
# **Recreate feature vector**

# %%
from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(
    inputCols=["total_events","purchases","total_spent","avg_price"],
    outputCol="features"
)

scoring_df = assembler.transform(full_features)

# %% [markdown]
# **Load Best Model (From MLflow)**

# %%
import mlflow.spark

model_uri = "runs:/a7aad4c2677742f58d6524843a429569/rf_model"
best_model = mlflow.spark.load_model(model_uri)
